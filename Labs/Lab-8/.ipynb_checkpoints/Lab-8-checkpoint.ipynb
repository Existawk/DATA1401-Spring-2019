# %% [markdown]
# # Lab 8
#
# In this lab we are going to start perform some data analysis. We will use numpy, pandas, and matplotlib, so lets import them:

# %%
# !pip install scikit-learn --user
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Requirement already satisfied: scikit-learn in /home1/06205/existawk/.local/lib/python2.7/site-packages
# Requirement already satisfied: numpy>=1.8.2 in /opt/apps/intel18/python2/2.7.15/lib/python2.7/site-packages/numpy-1.16.1-py2.7-linux-x86_64.egg (from scikit-learn)
# Requirement already satisfied: scipy>=0.13.3 in /opt/apps/intel18/python2/2.7.15/lib/python2.7/site-packages/scipy-1.2.0-py2.7-linux-x86_64.egg (from scikit-learn)
# You are using pip version 9.0.3, however version 19.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# We will focus on the heart dataset introduced in lecture 23. You can load the dataset using pandas:

# %%
df_heart=pd.read_csv("../../Lectures/Lecture-23/heart.csv")
df_heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# 7     44    1   1       120   263    0        1      173      0      0.0
# 8     52    1   2       172   199    1        1      162      0      0.5
# 9     57    1   2       150   168    0        1      174      0      1.6
# 10    54    1   0       140   239    0        1      160      0      1.2
# 11    48    0   2       130   275    0        1      139      0      0.2
# 12    49    1   1       130   266    0        1      171      0      0.6
# 13    64    1   3       110   211    0        0      144      1      1.8
# 14    58    0   3       150   283    1        0      162      0      1.0
# 15    50    0   2       120   219    0        1      158      0      1.6
# 16    58    0   2       120   340    0        1      172      0      0.0
# 17    66    0   3       150   226    0        1      114      0      2.6
# 18    43    1   0       150   247    0        1      171      0      1.5
# 19    69    0   3       140   239    0        1      151      0      1.8
# 20    59    1   0       135   234    0        1      161      0      0.5
# 21    44    1   2       130   233    0        1      179      1      0.4
# 22    42    1   0       140   226    0        1      178      0      0.0
# 23    61    1   2       150   243    1        1      137      1      1.0
# 24    40    1   3       140   199    0        1      178      1      1.4
# 25    71    0   1       160   302    0        1      162      0      0.4
# 26    59    1   2       150   212    1        1      157      0      1.6
# 27    51    1   2       110   175    0        1      123      0      0.6
# 28    65    0   2       140   417    1        0      157      0      0.8
# 29    53    1   2       130   197    1        0      152      0      1.2
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 273   58    1   0       100   234    0        1      156      0      0.1
# 274   47    1   0       110   275    0        0      118      1      1.0
# 275   52    1   0       125   212    0        1      168      0      1.0
# 276   58    1   0       146   218    0        1      105      0      2.0
# 277   57    1   1       124   261    0        1      141      0      0.3
# 278   58    0   1       136   319    1        0      152      0      0.0
# 279   61    1   0       138   166    0        0      125      1      3.6
# 280   42    1   0       136   315    0        1      125      1      1.8
# 281   52    1   0       128   204    1        1      156      1      1.0
# 282   59    1   2       126   218    1        1      134      0      2.2
# 283   40    1   0       152   223    0        1      181      0      0.0
# 284   61    1   0       140   207    0        0      138      1      1.9
# 285   46    1   0       140   311    0        1      120      1      1.8
# 286   59    1   3       134   204    0        1      162      0      0.8
# 287   57    1   1       154   232    0        0      164      0      0.0
# 288   57    1   0       110   335    0        1      143      1      3.0
# 289   55    0   0       128   205    0        2      130      1      2.0
# 290   61    1   0       148   203    0        1      161      0      0.0
# 291   58    1   0       114   318    0        2      140      0      4.4
# 292   58    0   0       170   225    1        0      146      1      2.8
# 293   67    1   2       152   212    0        0      150      0      0.8
# 294   44    1   0       120   169    0        1      144      1      2.8
# 295   63    1   0       140   187    0        0      144      1      4.0
# 296   63    0   0       124   197    0        1      136      1      0.0
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# 5        1   0     1       1
# 6        1   0     2       1
# 7        2   0     3       1
# 8        2   0     3       1
# 9        2   0     2       1
# 10       2   0     2       1
# 11       2   0     2       1
# 12       2   0     2       1
# 13       1   0     2       1
# 14       2   0     2       1
# 15       1   0     2       1
# 16       2   0     2       1
# 17       0   0     2       1
# 18       2   0     2       1
# 19       2   2     2       1
# 20       1   0     3       1
# 21       2   0     2       1
# 22       2   0     2       1
# 23       1   0     2       1
# 24       2   0     3       1
# 25       2   2     2       1
# 26       2   0     2       1
# 27       2   0     2       1
# 28       2   1     2       1
# 29       0   0     2       1
# ..     ...  ..   ...     ...
# 273      2   1     3       0
# 274      1   1     2       0
# 275      2   2     3       0
# 276      1   1     3       0
# 277      2   0     3       0
# 278      2   2     2       0
# 279      1   1     2       0
# 280      1   0     1       0
# 281      1   0     0       0
# 282      1   1     1       0
# 283      2   0     3       0
# 284      2   1     3       0
# 285      1   2     3       0
# 286      2   2     2       0
# 287      2   1     2       0
# 288      1   1     3       0
# 289      1   1     3       0
# 290      2   1     3       0
# 291      0   3     1       0
# 292      1   2     1       0
# 293      1   0     3       0
# 294      0   0     1       0
# 295      2   2     3       0
# 296      1   0     2       0
# 297      1   2     1       0
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# ** Exercise 1: ** Histogram every observable for each of the types of chest pain, for no chest pain, and for any chest pain. Make one figure for each observable, with 2 axes. On one axes compare no chest pain with any chest pain. On the other compare no chest pain with every chest pain catagory. Make sure that every category is uniquely represented in the histogram (e.g. different color). Don't forget to create legends, label axes, and put appropriate titles. In the legend, also indicate the mean and variance.
#
# Based on your histograms, rank the observables in terms their effectiveness of predicting of chest pain.

# %%
VarNames=["age","sex","cp","trestbps","chol","fbs","restecg","thalach","exang","oldpeak","slope","ca","thal","target"]
df_cp1=df_heart[df_heart.cp==1]
df_cp2=df_heart[df_heart.cp==2]
df_cp3=df_heart[df_heart.cp==3]
df_ncp=df_heart[df_heart.cp==0]
df_acp=df_heart[df_heart.cp!=0]
for var in VarNames[1:]:
    print var
    print "mean: ", np.mean(df_heart[var])
    print "Variance: ", np.var(df_heart[var])
    plt.figure(figsize=(10,5))
    plt.hist(np.array(df_cp1[var]),bins=100, color="yellow",label="Chest Pain: 1",normed=True, stacked=True)
    plt.hist(np.array(df_cp2[var]),bins=100, color="orange",label="Chest Pain: 2",normed=True, stacked=True)
    plt.hist(np.array(df_cp3[var]),bins=100, color="red",label="Chest Pain: 3",normed=True, stacked=True)
    plt.hist(np.array(df_ncp[var]),bins=100, color="blue",label="No Chest Pain",normed=True, stacked=True)
    plt.hist(np.array(df_acp[var]),bins=100, color="green",label="Any Chest Pain",normed=True, stacked=True)
    plt.legend(loc='upper right')
    plt.show()
# Out:
# sex
# mean:  0.6831683168316832
# Variance:  0.21644936770904813
# cp
# mean:  0.966996699669967
# Variance:  1.0616170527943882
# trestbps
# mean:  131.62376237623764
# Variance:  306.5713165375944
# chol
# mean:  246.26402640264027
# Variance:  2677.560653095012
# fbs
# mean:  0.1485148514851485
# Variance:  0.1264581903734928
# restecg
# mean:  0.528052805280528
# Variance:  0.2756156803799191
# thalach
# mean:  149.64686468646866
# Variance:  522.9148994107331
# exang
# mean:  0.32673267326732675
# Variance:  0.219978433486913
# oldpeak
# mean:  1.0396039603960396
# Variance:  1.3436460477730943
# slope
# mean:  1.3993399339933994
# Variance:  0.37848141249768535
# ca
# mean:  0.7293729372937293
# Variance:  1.0422725440860918
# thal
# mean:  2.3135313531353137
# Variance:  0.3736452853206113
# target
# mean:  0.5445544554455446
# Variance:  0.24801490049995092

# %% [markdown]
# ** Exercise 2: ** For the top 3 discrete observables, compute the True Positive Rate (TPR) and False Positive Rate (FPR) for predicting chest pain for each value of the observable. Present your results in tables.

# %%
observ=["exang","target","fbs"]
for obs in observ:
    h_d=np.where(df_heart["cp"]==0,df_heart["cp"],1)
    fpr, tpr, _ = roc_curve(h_d,df_heart[obs])
    print fpr,tpr
# Out:
# [0.         0.55944056 1.        ] [0.      0.11875 1.     ]
# [0.         0.27272727 1.        ] [0.     0.7875 1.    ]
# [0.         0.12587413 1.        ] [0.      0.16875 1.     ]

# %% [markdown]
# ** Exercise 3: ** For the top 3 continuous observables, draw a Reciever Operating Characteristic (ROC) curve and compute the area under the curve.

# %%
from sklearn.metrics import roc_curve, auc
def pos(y,z):
    h_d=np.where(df_heart["cp"]==0,df_heart["cp"],1)
    
    fpr, tpr, _ = roc_curve(h_d,y)

    roc_auc = auc(fpr, tpr)
    
    print z
    plt.plot(fpr,tpr,color='darkorange',label='ROC curve (area = %0.2f)' % roc_auc)
    plt.legend(loc="lower right")
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')

    plt.show()
    
pos(df_heart.thalach,"thalach")
pos(df_heart.age,"age")
pos(df_heart.trestbps,"trestbps")
# Out:
# thalach
# age
# trestbps

# %% [markdown]
# ** Exercise 4: ** Using numpy, compute the between-class $\bf{S}_B$ and within-class $\bf{S}_W$ covariance matrices defined as:
#
# $$
# \bf{S}_B = (\bf{m_2}-\bf{m_1})(\bf{m_2}-\bf{m_1})^T \\
# $$
# $$
# \bf{S}_W = \sum_{i=1,2} \sum_{n=1}^{l_i} (\bf{x}_n^i - \bf{m}_i) (\bf{x}_n^i - \bf{m}_i)^T
# $$
#
# where $\bf{m_i}$ are the vectors containing the means for category 1 and 2, here defined as no chest pain and any chest pain. Here $\bf{x}_n^i$ is the vector containing the observables for the $n$th example patient in category $i$.

# %%
Sb=(df_acp-df_ncp)*(df_acp-df_ncp)
Sw=np.cov(df_ncp,df_acp)
#sw use np covariance

# %% [markdown]
# ** Exercise 5:** Compute the linear coefficients $\bf{w} = \bf{S_W}^{-1}(\bf{m_2}-\bf{m_1})$. Compare the histogram of the distribution of $F_n^i=\bf{w}^T\bf{x}_n^i$ for the two categories.

# %%
#fisher's discrminant / liniar discrimanent analysis

# %% [markdown]
# ** Exercise 6: ** Draw the ROC curve for $F_n$. Select a "cut" value for $F_n$ which maximizes TPR / $\sqrt($ FPR + TPR $)$.

# %%
h_d=np.where(df_heart["cp"]==0,df_heart["cp"],1)

fpr, tpr, _ = roc_curve(h_d,Fn)

roc_auc = auc(fpr, tpr)

print "Fn"
plt.plot(fpr,tpr,color='darkorange',label='ROC curve (area = %0.2f)' % roc_auc)
plt.legend(loc="lower right")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.show()
